# %%
# %matplotlib inline

from tumorsphere.cells import *
from tumorsphere.culture import *

# %%
csc_culture = Culture(first_cell_is_stem=True)

# %%
data = csc_culture.simulate_with_data(8)

# %%
import matplotlib.pyplot as plt

# create a figure and axis objects
fig, ax = plt.subplots()

# plot each row of the array with custom labels and colors
ax.plot(data[0, :], label="Total", color="blue")
ax.plot(data[1, :], label="Total active", color="green")
ax.plot(data[2, :], label="Stem", color="orange")
ax.plot(data[3, :], label="Active stem", color="red")


# set the title and axis labels
ax.set_title("Simulation of CSC seeded culture")
ax.set_xlabel("Time step")
ax.set_ylabel("Number of cells")

# create a legend and display the plot
ax.legend()
plt.show()

# %%
# create a figure and axis objects
fig, ax = plt.subplots()

# plot each row of the array with custom labels and colors
#ax.plot(data[0, :], label="Total", color="blue")
#ax.plot(data[1, :], label="Stem", color="orange")
ax.plot(data[2, :], label="Stem", color="orange")
#ax.plot(data[3, :], label="Active stem", color="red")


# set the title and axis labels
ax.set_title("Simulation of CSC seeded culture")
ax.set_xlabel("Time step")
ax.set_ylabel("Number of cells")

# create a legend and display the plot
ax.legend()
plt.show()

# %%
# ======== BEFORE REPRODUCE LOOKED ONLY AT NEIGHBORS ========
#
# Time taken: 297.411220 seconds
#
# ======== AFTER REPRODUCE LOOKED ONLY AT NEIGHBORS ========

import time

# start the timer
start_time = time.perf_counter()

# code
csc_culture = Culture(first_cell_is_stem=True)
data = csc_culture.simulate_with_data(8)

# stop the timer
end_time = time.perf_counter()

# calculate the elapsed time
elapsed_time = end_time - start_time

# print the elapsed time
print(f"Time taken: {elapsed_time:.6f} seconds")
# Out:
# Time taken: 297.411220 seconds
