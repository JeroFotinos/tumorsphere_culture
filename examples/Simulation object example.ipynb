# %%
# %matplotlib inline

from tumorsphere.cells import *
from tumorsphere.culture import *
from tumorsphere.simulation import *

# %%
sim = Simulation(
    first_cell_is_stem=True,
    prob_stem=[0.36],  # Wang HARD substrate value
    prob_diff=[0],
    num_of_realizations=3,
    num_of_steps_per_realization=4,
    rng_seed=0x87351080E25CB0FAD77A44A3BE03B491,
    cell_radius=1,
    adjacency_threshold=4,
    cell_max_repro_attempts=1000,
    continuous_graph_generation=False,
)

# %%
sim.simulate()
# pickle.dump(sim.dic)

# %%
fig, ax = sim.plot_average_data(ps_index=0, pd_index=0)
plt.show()

# %%
larger_sim = Simulation(
    first_cell_is_stem=True,
    prob_stem=[0.3, 0.6, 0.9],  # Wang HARD substrate value
    num_of_realizations=10,
    num_of_steps_per_realization=10,
    rng_seed=0x87351080E25CB0FAD77A44A3BE03B491,
    cell_radius=1,
    adjacency_threshold=4,
    cell_max_repro_attempts=1000,
    continuous_graph_generation=False,
)

# %%
larger_sim.simulate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 larger_sim.simulate()
#
# File ~/Devel/tumorsphere_culture/tumorsphere/simulation.py:71, in Simulation.simulate(self)
#      58     self.cultures[current_realization_name] = Culture(
#      59         adjacency_threshold=self.adjacency_threshold,
#      60         cell_radius=self.cell_radius,
#    (...)
#      65         rng_seed=self.rng.integers(low=2**20, high=2**50),
#      66     )
#      67     # we simulate the culture's growth and retrive data in the
#      68     # self.data dictionary, with the same string as key
#      69     self.data[current_realization_name] = self.cultures[
#      70         current_realization_name
# ---> 71     ].simulate_with_data(self.num_of_steps_per_realization)
#      72 # now we compute the averages
#      73 # self.average_data[:, :, i] = np.vstack((self.average_of_data_row_k_and_ps_i(k, i) for k in range(4)))
#      74 self.average_data[:, :, i] = np.vstack(
#      75     (
#      76         self.average_of_data_row_k_and_ps_i(0, i),
#    (...)
#      80     )
#      81 )
#
# File ~/Devel/tumorsphere_culture/tumorsphere/culture.py:173, in Culture.simulate_with_data(self, num_times)
#     170 # I had to point to the cells in a copied list,
#     171 # if not, strange things happened
#     172 for cell in cells:
# --> 173     cell.reproduce()
#     175 # we count the number of CSCs in this time step
#     176 total_stem_counter = 0
#
# File ~/Devel/tumorsphere_culture/tumorsphere/cells.py:186, in Cell.reproduce(self)
#     183 for attempt in range(self.max_repro_attempts):
#     184     child_position = self.generate_new_position()
#     185     neighbors_up_to_second_degree = (
# --> 186         self.get_list_of_neighbors_up_to_second_degree()
#     187     )
#     188     # array with the distances from the proposed child position to the other cells
#     189     distance = np.array(
#     190         [
#     191             np.linalg.norm(child_position - cell.position)
#     192             for cell in neighbors_up_to_second_degree
#     193         ]
#     194     )
#
# File ~/Devel/tumorsphere_culture/tumorsphere/cells.py:94, in Cell.get_list_of_neighbors_up_to_second_degree(self)
#      89     neighbors_up_to_second_degree = (
#      90         neighbors_up_to_second_degree.union(set(cell1.neighbors))
#      91     )
#      92     for cell2 in cell1.neighbors:
#      93         neighbors_up_to_second_degree = (
# ---> 94             neighbors_up_to_second_degree.union(set(cell2.neighbors))
#      95         )
#      96 neighbors_up_to_second_degree = list(neighbors_up_to_second_degree)
#      97 return neighbors_up_to_second_degree
#
# KeyboardInterrupt:

# %%
# fig for p_s = 0.3
fig, ax = larger_sim.plot_average_data(0)
plt.show()

# %%
# fig for p_s = 0.6
fig, ax = larger_sim.plot_average_data(1)
plt.show()

# %%
# fig for p_s = 0.9
fig, ax = larger_sim.plot_average_data(2)
plt.show()
